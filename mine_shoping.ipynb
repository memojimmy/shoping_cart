# %%
import pandas as pd 
import numpy as np 
import plotly.express as px

# %%
customers = pd.read_csv('customers.csv')
sales = pd.read_csv('sales.csv')
products = pd.read_csv('products.csv')
orders = pd.read_csv('orders.csv')

# %%
customers.head()
# Out:
#    customer_id        customer_name       gender  age  \
# 0            1        Leanna Busson       Female   30
# 1            2  Zabrina Harrowsmith  Genderfluid   69
# 2            3      Shina Dullaghan   Polygender   59
# 3            4        Hewet McVitie     Bigender   67
# 4            5       Rubia Ashleigh   Polygender   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1000 non-null   int64
#  1   customer_name  1000 non-null   str
#  2   gender         1000 non-null   str
#  3   age            1000 non-null   int64
#  4   home_address   1000 non-null   str
#  5   zip_code       1000 non-null   int64
#  6   city           1000 non-null   str
#  7   state          1000 non-null   str
#  8   country        1000 non-null   str
# dtypes: int64(3), str(6)
# memory usage: 151.7 KB

# %%
customers.describe()
# Out:
#        customer_id          age     zip_code
# count  1000.000000  1000.000000  1000.000000
# mean    500.500000    49.860000  5004.872000
# std     288.819436    17.647828  2884.497332
# min       1.000000    20.000000     2.000000
# 25%     250.750000    34.000000  2401.750000
# 50%     500.500000    50.000000  5083.000000
# 75%     750.250000    65.000000  7460.250000
# max    1000.000000    80.000000  9998.000000

# %%
customers.columns
# Out:
# Index(['customer_id', 'customer_name', 'gender', 'age', 'home_address',
#        'zip_code', 'city', 'state', 'country'],
#       dtype='str')

# %%
customers.head()
# Out:
#    customer_id        customer_name       gender  age  \
# 0            1        Leanna Busson       Female   30
# 1            2  Zabrina Harrowsmith  Genderfluid   69
# 2            3      Shina Dullaghan   Polygender   59
# 3            4        Hewet McVitie     Bigender   67
# 4            5       Rubia Ashleigh   Polygender   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %%
customers.describe(include='object')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11496\2762918133.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   customers.describe(include='object')
#         customer_name gender                    home_address        city  \
# count            1000   1000                            1000        1000
# unique           1000      8                            1000         961
# top     Leanna Busson   Male  8606 Victoria TerraceSuite 560  East Aidan
# freq                1    143                               1           3
#
#                   state    country
# count              1000       1000
# unique                8          1
# top     South Australia  Australia
# freq                139       1000

# %%
products.head()
# Out:
#    product_ID product_type  product_name size colour  price  quantity  \
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47
#
#                                     description
# 0  A red coloured, XS sized, Oxford Cloth Shirt
# 1   A red coloured, S sized, Oxford Cloth Shirt
# 2   A red coloured, M sized, Oxford Cloth Shirt
# 3   A red coloured, L sized, Oxford Cloth Shirt
# 4  A red coloured, XL sized, Oxford Cloth Shirt

# %%
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_ID    1260 non-null   int64
#  1   product_type  1260 non-null   str
#  2   product_name  1260 non-null   str
#  3   size          1260 non-null   str
#  4   colour        1260 non-null   str
#  5   price         1260 non-null   int64
#  6   quantity      1260 non-null   int64
#  7   description   1260 non-null   str
# dtypes: int64(3), str(5)
# memory usage: 158.1 KB

# %%
products['description']
# Out:
# 0            A red coloured, XS sized, Oxford Cloth Shirt
# 1             A red coloured, S sized, Oxford Cloth Shirt
# 2             A red coloured, M sized, Oxford Cloth Shirt
# 3             A red coloured, L sized, Oxford Cloth Shirt
# 4            A red coloured, XL sized, Oxford Cloth Shirt
#                               ...
# 1255    A violet coloured, XS sized, Tracksuit Bottoms...
# 1256    A violet coloured, S sized, Tracksuit Bottoms ...
# 1257    A violet coloured, M sized, Tracksuit Bottoms ...
# 1258    A violet coloured, L sized, Tracksuit Bottoms ...
# 1259    A violet coloured, XL sized, Tracksuit Bottoms...
# Name: description, Length: 1260, dtype: str

# %%
products.describe(include='object')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11496\2740589634.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   products.describe(include='object')
#        product_type product_name  size colour  \
# count          1260         1260  1260   1260
# unique            3           35     5      7
# top           Shirt        Denim    XS    red
# freq            420           70   252    180
#
#                                          description
# count                                           1260
# unique                                          1260
# top     A red coloured, XS sized, Oxford Cloth Shirt
# freq                                               1

# %%
sales.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0         0         1         218             106         2          212
# 1         1         1         481             118         1          118
# 2         2         1           2              96         3          288
# 3         3         1        1002             106         2          212
# 4         4         1         691             113         3          339

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     5000 non-null   int64
# dtypes: int64(6)
# memory usage: 234.5 KB

# %%
sales.describe().round(2)
# Out:
#        sales_id  order_id  product_id  price_per_unit  quantity  total_price
# count   5000.00   5000.00     5000.00          5000.0   5000.00      5000.00
# mean    2499.50    503.04      634.05           103.5      1.99       206.36
# std     1443.52    285.96      363.26             9.2      0.81        86.36
# min        0.00      1.00        1.00            90.0      1.00        90.00
# 25%     1249.75    258.00      323.00            95.0      1.00       112.00
# 50%     2499.50    504.50      635.00           102.0      2.00       204.00
# 75%     3749.25    749.00      951.00           112.0      3.00       285.00
# max     4999.00    999.00     1259.00           119.0      3.00       357.00

# %%
orders.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   str
#  4   delivery_date  1000 non-null   str
# dtypes: int64(3), str(2)
# memory usage: 57.5 KB

# %%
orders.describe().round(2)
# Out:
#        order_id  customer_id   payment
# count   1000.00      1000.00   1000.00
# mean     500.50       506.64  33972.94
# std      288.82       277.12  14451.61
# min        1.00         1.00  10043.00
# 25%      250.75       275.25  21329.25
# 50%      500.50       515.00  33697.50
# 75%      750.25       737.25  46249.00
# max     1000.00      1000.00  59910.00

# %%
sales
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0            0         1         218             106         2          212
# 1            1         1         481             118         1          118
# 2            2         1           2              96         3          288
# 3            3         1        1002             106         2          212
# 4            4         1         691             113         3          339
# ...        ...       ...         ...             ...       ...          ...
# 4995      4995       998         321             109         2          218
# 4996      4996       998         251              95         3          285
# 4997      4997       999         872             113         1          113
# 4998      4998       999         998             106         2          212
# 4999      4999       999        1105             115         1          115
#
# [5000 rows x 6 columns]

# %%
products
# Out:
#       product_ID product_type       product_name size  colour  price  \
# 0              0        Shirt       Oxford Cloth   XS     red    114
# 1              1        Shirt       Oxford Cloth    S     red    114
# 2              2        Shirt       Oxford Cloth    M     red    114
# 3              3        Shirt       Oxford Cloth    L     red    114
# 4              4        Shirt       Oxford Cloth   XL     red    114
# ...          ...          ...                ...  ...     ...    ...
# 1255        1255     Trousers  Tracksuit Bottoms   XS  violet     91
# 1256        1256     Trousers  Tracksuit Bottoms    S  violet     91
# 1257        1257     Trousers  Tracksuit Bottoms    M  violet     91
# 1258        1258     Trousers  Tracksuit Bottoms    L  violet     91
# 1259        1259     Trousers  Tracksuit Bottoms   XL  violet     91
#
#       quantity                                        description
# 0           66       A red coloured, XS sized, Oxford Cloth Shirt
# 1           53        A red coloured, S sized, Oxford Cloth Shirt
# 2           54        A red coloured, M sized, Oxford Cloth Shirt
# 3           69        A red coloured, L sized, Oxford Cloth Shirt
# 4           47       A red coloured, XL sized, Oxford Cloth Shirt
# ...        ...                                                ...
# 1255        67  A violet coloured, XS sized, Tracksuit Bottoms...
# 1256        48  A violet coloured, S sized, Tracksuit Bottoms ...
# 1257        73  A violet coloured, M sized, Tracksuit Bottoms ...
# 1258        45  A violet coloured, L sized, Tracksuit Bottoms ...
# 1259        60  A violet coloured, XL sized, Tracksuit Bottoms...
#
# [1260 rows x 8 columns]

# %%
df = pd.merge(left=orders , right=customers , how='inner' , on='customer_id')

df = pd.merge(left= df , right=sales , how= 'inner' , on='order_id')

df = pd.merge(left= df , right=products , how= 'inner' , left_on='product_id' ,right_on='product_ID')

# %%
pd.set_option('display.max_columns' ,None)

# %%
df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date     customer_name  \
# 0         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
# 1         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
# 2         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
# 3         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
# 4         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
#
#         gender  age               home_address  zip_code            city  \
# 0  Genderfluid   75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 1  Genderfluid   75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 2  Genderfluid   75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 3  Genderfluid   75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 4  Genderfluid   75  4927 Alice MeadowApt. 960      7787  Sanfordborough
#
#              state    country  sales_id  product_id  price_per_unit  \
# 0  South Australia  Australia         0         218             106
# 1  South Australia  Australia         1         481             118
# 2  South Australia  Australia         2           2              96
# 3  South Australia  Australia         3        1002             106
# 4  South Australia  Australia         4         691             113
#
#    quantity_x  total_price  product_ID product_type  product_name size  \
# 0           2          212         218        Shirt      Chambray    L
# 1           1          118         481       Jacket        Puffer    S
# 2           3          288           2        Shirt  Oxford Cloth    M
# 3           2          212        1002     Trousers          Wool    M
# 4           3          339         691       Jacket         Parka    S
#
#    colour  price  quantity_y                                  description
# 0  orange    105          44   A orange coloured, L sized, Chambray Shirt
# 1  indigo    110          62    A indigo coloured, S sized, Puffer Jacket
# 2     red    114          54  A red coloured, M sized, Oxford Cloth Shirt
# 3    blue    111          52      A blue coloured, M sized, Wool Trousers
# 4  indigo    119          53     A indigo coloured, S sized, Parka Jacket

# %%
df.rename(columns={'quantity_x':'quantity','quantity_y' : 'stock'},inplace=True)

# %%
df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date     customer_name  \
# 0         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
# 1         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
# 2         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
# 3         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
# 4         1           64    30811  2021-8-30    2021-09-24  Annabella Devote
#
#         gender  age               home_address  zip_code            city  \
# 0  Genderfluid   75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 1  Genderfluid   75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 2  Genderfluid   75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 3  Genderfluid   75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 4  Genderfluid   75  4927 Alice MeadowApt. 960      7787  Sanfordborough
#
#              state    country  sales_id  product_id  price_per_unit  quantity  \
# 0  South Australia  Australia         0         218             106         2
# 1  South Australia  Australia         1         481             118         1
# 2  South Australia  Australia         2           2              96         3
# 3  South Australia  Australia         3        1002             106         2
# 4  South Australia  Australia         4         691             113         3
#
#    total_price  product_ID product_type  product_name size  colour  price  \
# 0          212         218        Shirt      Chambray    L  orange    105
# 1          118         481       Jacket        Puffer    S  indigo    110
# 2          288           2        Shirt  Oxford Cloth    M     red    114
# 3          212        1002     Trousers          Wool    M    blue    111
# 4          339         691       Jacket         Parka    S  indigo    119
#
#    stock                                  description
# 0     44   A orange coloured, L sized, Chambray Shirt
# 1     62    A indigo coloured, S sized, Puffer Jacket
# 2     54  A red coloured, M sized, Oxford Cloth Shirt
# 3     52      A blue coloured, M sized, Wool Trousers
# 4     53     A indigo coloured, S sized, Parka Jacket

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        5000 non-null   int64
#  1   customer_id     5000 non-null   int64
#  2   payment         5000 non-null   int64
#  3   order_date      5000 non-null   str
#  4   delivery_date   5000 non-null   str
#  5   customer_name   5000 non-null   str
#  6   gender          5000 non-null   str
#  7   age             5000 non-null   int64
#  8   home_address    5000 non-null   str
#  9   zip_code        5000 non-null   int64
#  10  city            5000 non-null   str
#  11  state           5000 non-null   str
#  12  country         5000 non-null   str
#  13  sales_id        5000 non-null   int64
#  14  product_id      5000 non-null   int64
#  15  price_per_unit  5000 non-null   int64
#  16  quantity        5000 non-null   int64
#  17  total_price     5000 non-null   int64
#  18  product_ID      5000 non-null   int64
#  19  product_type    5000 non-null   str
#  20  product_name    5000 non-null   str
#  21  size            5000 non-null   str
#  22  colour          5000 non-null   str
#  23  price           5000 non-null   int64
#  24  stock           5000 non-null   int64
#  25  description     5000 non-null   str
# dtypes: int64(13), str(13)
# memory usage: 1.8 MB

# %%
df.describe().round(2)
# Out:
#        order_id  customer_id   payment      age  zip_code  sales_id  \
# count   5000.00      5000.00   5000.00  5000.00   5000.00   5000.00
# mean     503.04       504.56  33976.79    48.76   4912.36   2499.50
# std      285.96       276.50  14612.71    17.58   2907.37   1443.52
# min        1.00         1.00  10043.00    20.00     52.00      0.00
# 25%      258.00       276.00  20627.00    34.00   2273.00   1249.75
# 50%      504.50       509.00  34259.00    48.00   4750.00   2499.50
# 75%      749.00       733.00  46608.00    63.00   7460.25   3749.25
# max      999.00      1000.00  59910.00    80.00   9998.00   4999.00
#
#        product_id  price_per_unit  quantity  total_price  product_ID    price  \
# count     5000.00          5000.0   5000.00      5000.00     5000.00  5000.00
# mean       634.05           103.5      1.99       206.36      634.05   105.67
# std        363.26             9.2      0.81        86.36      363.26     9.74
# min          1.00            90.0      1.00        90.00        1.00    90.00
# 25%        323.00            95.0      1.00       112.00      323.00    95.00
# 50%        635.00           102.0      2.00       204.00      635.00   108.00
# 75%        951.00           112.0      3.00       285.00      951.00   114.00
# max       1259.00           119.0      3.00       357.00     1259.00   119.00
#
#          stock
# count  5000.00
# mean     60.08
# std      11.68
# min      40.00
# 25%      50.00
# 50%      60.00
# 75%      70.00
# max      80.00

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['delivery_date'] = pd.to_datetime(df['delivery_date'])

# %%
df.drop(columns=['country','payment','customer_id','sales_id','zip_code','home_address'] ,inplace=True)

# %%
df.head()
# Out:
#    order_id order_date delivery_date     customer_name       gender  age  \
# 0         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 1         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 2         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 3         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 4         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
#
#              city            state  product_id  price_per_unit  quantity  \
# 0  Sanfordborough  South Australia         218             106         2
# 1  Sanfordborough  South Australia         481             118         1
# 2  Sanfordborough  South Australia           2              96         3
# 3  Sanfordborough  South Australia        1002             106         2
# 4  Sanfordborough  South Australia         691             113         3
#
#    total_price  product_ID product_type  product_name size  colour  price  \
# 0          212         218        Shirt      Chambray    L  orange    105
# 1          118         481       Jacket        Puffer    S  indigo    110
# 2          288           2        Shirt  Oxford Cloth    M     red    114
# 3          212        1002     Trousers          Wool    M    blue    111
# 4          339         691       Jacket         Parka    S  indigo    119
#
#    stock                                  description
# 0     44   A orange coloured, L sized, Chambray Shirt
# 1     62    A indigo coloured, S sized, Puffer Jacket
# 2     54  A red coloured, M sized, Oxford Cloth Shirt
# 3     52      A blue coloured, M sized, Wool Trousers
# 4     53     A indigo coloured, S sized, Parka Jacket

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True ,ignore_index=True)

# %%
cat_col = df.select_dtypes(include='object').columns
cat_col
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11496\113230759.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_col = df.select_dtypes(include='object').columns
# Index(['customer_name', 'gender', 'city', 'state', 'product_type',
#        'product_name', 'size', 'colour', 'description'],
#       dtype='str')

# %%
for col in cat_col:
    print(col)
    print(df[col])
    print(df[col].unique())
    print(df[col].nunique())
    print('\n' , '=' * 100 , '\n')
# Out:
# customer_name
# 0       Annabella Devote
# 1       Annabella Devote
# 2       Annabella Devote
# 3       Annabella Devote
# 4       Annabella Devote
#               ...
# 4994      Murdock Bulfit
# 4995      Murdock Bulfit
# 4996       Jammal Varcoe
# 4997       Jammal Varcoe
# 4998       Jammal Varcoe
# Name: customer_name, Length: 4999, dtype: str
# <ArrowStringArray>
# [    'Annabella Devote',          'Lori Briars',         'Ellynn Korba',
#       'Candis Roswarne',  'Artemas Vasilischev',        'Katusha Ceney',
#         'Tann Scothron',        'Aurie Margett',         'Lucas Cromly',
#          'Ira Dafforne',
#  ...
#  'Augustin Brandenberg',           'Erik Osgar',         'John Panchen',
#   'Barbara-anne Salerg',      'Thorsten Sowrey',    'Muire Ashtonhurst',
#         'Curcio Kiffin',      'Merrielle Piken',      'Kerianne Parris',
#        'Murdock Bulfit']
# Length: 616, dtype: str
# 616
#
#  ====================================================================================================
#
# gender
# 0       Genderfluid
# 1       Genderfluid
# 2       Genderfluid
# 3       Genderfluid
# 4       Genderfluid
#            ...
# 4994           Male
# 4995           Male
# 4996     Polygender
# 4997     Polygender
# 4998     Polygender
# Name: gender, Length: 4999, dtype: str
# <ArrowStringArray>
# ['Genderfluid',        'Male', 'Genderqueer',  'Non-binary',    'Bigender',
#      'Agender',  'Polygender',      'Female']
# Length: 8, dtype: str
# 8
#
#  ====================================================================================================
#
# city
# 0       Sanfordborough
# 1       Sanfordborough
# 2       Sanfordborough
# 3       Sanfordborough
# 4       Sanfordborough
#              ...
# 4994     Hartmannshire
# 4995     Hartmannshire
# 4996    North Liamfort
# 4997    North Liamfort
# 4998    North Liamfort
# Name: city, Length: 4999, dtype: str
# <ArrowStringArray>
# [    'Sanfordborough',            'Annaton', 'West Jonathanshire',
#    'West Michaelport',    'South Rileyview',      'Daughertyport',
#          'Walterstad',        'Amelieburgh',       'O'connertown',
#         'Sophiemouth',
#  ...
#         'East Lauren',     'Zacharyborough',         'Evansburgh',
#        'Savannahland',      'Port Isabelle',       'West Michael',
#     'Rutherfordville',         'Audreyfurt',          'Olsonbury',
#       'Hartmannshire']
# Length: 604, dtype: str
# 604
#
#  ====================================================================================================
#
# state
# 0                    South Australia
# 1                    South Australia
# 2                    South Australia
# 3                    South Australia
# 4                    South Australia
#                     ...
# 4994                      Queensland
# 4995                      Queensland
# 4996    Australian Capital Territory
# 4997    Australian Capital Territory
# 4998    Australian Capital Territory
# Name: state, Length: 4999, dtype: str
# <ArrowStringArray>
# [             'South Australia',                     'Tasmania',
#             'Western Australia',                   'Queensland',
#               'New South Wales',           'Northern Territory',
#                      'Victoria', 'Australian Capital Territory']
# Length: 8, dtype: str
# 8
#
#  ====================================================================================================
#
# product_type
# 0          Shirt
# 1         Jacket
# 2          Shirt
# 3       Trousers
# 4         Jacket
#           ...
# 4994       Shirt
# 4995       Shirt
# 4996    Trousers
# 4997    Trousers
# 4998    Trousers
# Name: product_type, Length: 4999, dtype: str
# <ArrowStringArray>
# ['Shirt', 'Jacket', 'Trousers']
# Length: 3, dtype: str
# 3
#
#  ====================================================================================================
#
# product_name
# 0              Chambray
# 1                Puffer
# 2          Oxford Cloth
# 3                  Wool
# 4                 Parka
#              ...
# 4994    Mandarin Collar
# 4995               Polo
# 4996             Chinos
# 4997               Wool
# 4998            Cropped
# Name: product_name, Length: 4999, dtype: str
# <ArrowStringArray>
# [         'Chambray',            'Puffer',      'Oxford Cloth',
#               'Wool',             'Parka',        'Drawstring',
#            'Cropped',           'Pleated',             'Linen',
#       'High-Waisted',             'Dress',       'Relaxed Leg',
#            'Peacoat',         'Shearling',             'Coach',
#           'Pullover',            'Chinos',              'Polo',
#      'Camp Collared',       'Trench Coat',           'Joggers',
#    'Mandarin Collar',             'Denim',             'Cords',
#            'Flannel', 'Tracksuit Bottoms',      'Cuban Collar',
#           'Slim-Fit',            'Henley',            'Bomber',
#           'Cardigan',       'Windbreaker',   'Casual Slim Fit',
#            'Leather',       'Cargo Pants']
# Length: 35, dtype: str
# 35
#
#  ====================================================================================================
#
# size
# 0        L
# 1        S
# 2        M
# 3        M
# 4        S
#         ..
# 4994     S
# 4995     S
# 4996     M
# 4997     L
# 4998    XS
# Name: size, Length: 4999, dtype: str
# <ArrowStringArray>
# ['L', 'S', 'M', 'XS', 'XL']
# Length: 5, dtype: str
# 5
#
#  ====================================================================================================
#
# colour
# 0       orange
# 1       indigo
# 2          red
# 3         blue
# 4       indigo
#          ...
# 4994    orange
# 4995    orange
# 4996    violet
# 4997     green
# 4998      blue
# Name: colour, Length: 4999, dtype: str
# <ArrowStringArray>
# ['orange', 'indigo', 'red', 'blue', 'green', 'violet', 'yellow']
# Length: 7, dtype: str
# 7
#
#  ====================================================================================================
#
# description
# 0              A orange coloured, L sized, Chambray Shirt
# 1               A indigo coloured, S sized, Puffer Jacket
# 2             A red coloured, M sized, Oxford Cloth Shirt
# 3                 A blue coloured, M sized, Wool Trousers
# 4                A indigo coloured, S sized, Parka Jacket
#                               ...
# 4994    A orange coloured, S sized, Mandarin Collar Shirt
# 4995               A orange coloured, S sized, Polo Shirt
# 4996          A violet coloured, M sized, Chinos Trousers
# 4997             A green coloured, L sized, Wool Trousers
# 4998          A blue coloured, XS sized, Cropped Trousers
# Name: description, Length: 4999, dtype: str
# <ArrowStringArray>
# [      'A orange coloured, L sized, Chambray Shirt',
#         'A indigo coloured, S sized, Puffer Jacket',
#       'A red coloured, M sized, Oxford Cloth Shirt',
#           'A blue coloured, M sized, Wool Trousers',
#          'A indigo coloured, S sized, Parka Jacket',
#            'A red coloured, S sized, Wool Trousers',
#  'A orange coloured, XS sized, Drawstring Trousers',
#            'A blue coloured, S sized, Parka Jacket',
#      'A orange coloured, S sized, Cropped Trousers',
#      'A orange coloured, S sized, Pleated Trousers',
#  ...
#          'A yellow coloured, XS sized, Linen Shirt',
#       'A violet coloured, XL sized, Leather Jacket',
#            'A green coloured, L sized, Dress Shirt',
#      'A violet coloured, XL sized, Cardigan Jacket',
#          'A indigo coloured, M sized, Henley Shirt',
#     'A blue coloured, XS sized, Windbreaker Jacket',
#           'A yellow coloured, XS sized, Polo Shirt',
#          'A red coloured, XS sized, Peacoat Jacket',
#         'A indigo coloured, XL sized, Coach Jacket',
#          'A green coloured, L sized, Wool Trousers']
# Length: 1233, dtype: str
# 1233
#
#  ====================================================================================================

# %%
num_col = df.select_dtypes(include='number').columns.drop(['order_id','product_id'])
num_col
# Out:
# Index(['age', 'price_per_unit', 'quantity', 'total_price', 'product_ID',
#        'price', 'stock'],
#       dtype='str')

# %%
for col in num_col:
    px.histogram(data_frame=df ,x=col ,title=col).show()

# %%
df.head()
# Out:
#    order_id order_date delivery_date     customer_name       gender  age  \
# 0         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 1         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 2         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 3         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 4         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
#
#              city            state  product_id  price_per_unit  quantity  \
# 0  Sanfordborough  South Australia         218             106         2
# 1  Sanfordborough  South Australia         481             118         1
# 2  Sanfordborough  South Australia           2              96         3
# 3  Sanfordborough  South Australia        1002             106         2
# 4  Sanfordborough  South Australia         691             113         3
#
#    total_price  product_ID product_type  product_name size  colour  price  \
# 0          212         218        Shirt      Chambray    L  orange    105
# 1          118         481       Jacket        Puffer    S  indigo    110
# 2          288           2        Shirt  Oxford Cloth    M     red    114
# 3          212        1002     Trousers          Wool    M    blue    111
# 4          339         691       Jacket         Parka    S  indigo    119
#
#    stock                                  description
# 0     44   A orange coloured, L sized, Chambray Shirt
# 1     62    A indigo coloured, S sized, Puffer Jacket
# 2     54  A red coloured, M sized, Oxford Cloth Shirt
# 3     52      A blue coloured, M sized, Wool Trousers
# 4     53     A indigo coloured, S sized, Parka Jacket

# %% [markdown]
# feature Engineering (Extraction)

# %%
df['time_arrivale'] = df.delivery_date - df.order_date

# %%
df.head()
# Out:
#    order_id order_date delivery_date     customer_name       gender  age  \
# 0         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 1         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 2         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 3         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 4         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
#
#              city            state  product_id  price_per_unit  quantity  \
# 0  Sanfordborough  South Australia         218             106         2
# 1  Sanfordborough  South Australia         481             118         1
# 2  Sanfordborough  South Australia           2              96         3
# 3  Sanfordborough  South Australia        1002             106         2
# 4  Sanfordborough  South Australia         691             113         3
#
#    total_price  product_ID product_type  product_name size  colour  price  \
# 0          212         218        Shirt      Chambray    L  orange    105
# 1          118         481       Jacket        Puffer    S  indigo    110
# 2          288           2        Shirt  Oxford Cloth    M     red    114
# 3          212        1002     Trousers          Wool    M    blue    111
# 4          339         691       Jacket         Parka    S  indigo    119
#
#    stock                                  description time_arrivale
# 0     44   A orange coloured, L sized, Chambray Shirt       25 days
# 1     62    A indigo coloured, S sized, Puffer Jacket       25 days
# 2     54  A red coloured, M sized, Oxford Cloth Shirt       25 days
# 3     52      A blue coloured, M sized, Wool Trousers       25 days
# 4     53     A indigo coloured, S sized, Parka Jacket       25 days

# %%
df['time_arrivale']=df['time_arrivale'].astype('str').str.split().str[0].astype('int')

# %%
# !pip install  --upgrade nbformat>=4.2.0

# %%
px.histogram(data_frame=df ,x=df['time_arrivale'])

# %%
df.head()
# Out:
#    order_id order_date delivery_date     customer_name       gender  age  \
# 0         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 1         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 2         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 3         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
# 4         1 2021-08-30    2021-09-24  Annabella Devote  Genderfluid   75
#
#              city            state  product_id  price_per_unit  quantity  \
# 0  Sanfordborough  South Australia         218             106         2
# 1  Sanfordborough  South Australia         481             118         1
# 2  Sanfordborough  South Australia           2              96         3
# 3  Sanfordborough  South Australia        1002             106         2
# 4  Sanfordborough  South Australia         691             113         3
#
#    total_price  product_ID product_type  product_name size  colour  price  \
# 0          212         218        Shirt      Chambray    L  orange    105
# 1          118         481       Jacket        Puffer    S  indigo    110
# 2          288           2        Shirt  Oxford Cloth    M     red    114
# 3          212        1002     Trousers          Wool    M    blue    111
# 4          339         691       Jacket         Parka    S  indigo    119
#
#    stock                                  description  time_arrivale
# 0     44   A orange coloured, L sized, Chambray Shirt             25
# 1     62    A indigo coloured, S sized, Puffer Jacket             25
# 2     54  A red coloured, M sized, Oxford Cloth Shirt             25
# 3     52      A blue coloured, M sized, Wool Trousers             25
# 4     53     A indigo coloured, S sized, Parka Jacket             25

# %%
px.pie(data_frame=df ,names='product_type')

# %%
top_5_state = df.groupby(df['state'])['total_price'].sum().reset_index().head(5).sort_values(by='total_price' ,ascending=False)

# %%
px.bar(data_frame=top_5_state ,x='state',y='total_price',text_auto='True')

# %%
df['delivery_date']=df['delivery_date'].sort_values()

# %%
# Revenue over time 
rev_over_time = df.groupby(df['delivery_date'])['total_price'].sum().reset_index()
rev_over_time
# Out:
#     delivery_date  total_price
# 0      2021-01-03         1478
# 1      2021-01-05         1163
# 2      2021-01-06         1081
# 3      2021-01-07         1057
# 4      2021-01-08         1907
# ..            ...          ...
# 299    2021-11-13         2347
# 300    2021-11-14         1450
# 301    2021-11-16         2043
# 302    2021-11-17         1579
# 303    2021-11-20          941
#
# [304 rows x 2 columns]

# %%
px.line(data_frame=rev_over_time, x='delivery_date' , y='total_price')

# %%
#cumulative revenue over time 
df['cumulative'] = df.total_price.cumsum()
df.cumulative
# Out:
# 0           212
# 1           330
# 2           618
# 3           830
# 4          1169
#          ...
# 4994    1030769
# 4995    1031054
# 4996    1031167
# 4997    1031379
# 4998    1031494
# Name: cumulative, Length: 4999, dtype: int64

# %%
df.to_csv('cleaned_data.csv')

# %%
import streamlit as st

# %%
# %%writefile shoping_cart.py

import pandas as pd 
import numpy as np 
import streamlit as st 
import plotly.express as px

st.set_page_config(layout= 'wide', page_title= 'Shopping Cart EDA')

html_title = """<h1 style="color:white;text-align:center;"> Shopping Cart Exploratory Data Analysis </h1>"""
st.markdown(html_title, unsafe_allow_html=True)

st.image('WhatsApp Image 2026-02-02 at 4.47.13 PM.jpeg')

df = pd.read_csv('cleaned_data.csv', index_col= 0)

page = st.sidebar.radio('Pages', ['Home', "KPI's Dashboard", "Marketing Report"])

if page == 'Home':

    st.subheader('Dataset Overview')
    st.dataframe(df)

    column_descriptions = {
    "order_id": "Unique identifier for each order.",
    "order_date": "Date when the order was placed.",
    "delivery_date": "Date when the order was delivered.",
    "customer_name": "Full name of the customer who placed the order.",
    "gender": "Gender of the customer.",
    "age": "Age of the customer.",
    "city": "City where the customer resides.",
    "state": "State where the customer resides.",
    "product_id": "Unique identifier for each product.",
    "price_per_unit": "Price per single unit of the product.",
    "quantity": "Number of units purchased in the order.",
    "total_price": "Total cost for that product (quantity × price_per_unit).",
    "product_type": "Type or category of the product (e.g., Shirt, Jacket, etc.).",
    "product_name": "Specific name or style of the product.",
    "size": "Size of the product (e.g., S, M, L, etc.).",
    "colour": "Colour of the product.",
    "stock": "Current number of units available in inventory.",
    "delivery_duration": "Number of days between order_date and delivery_date."}

    # Create a table for descriptions
    desc_df = pd.DataFrame(list(column_descriptions.items()), columns=["Column Name", "Description"])

    # Display table
    st.subheader("📝 Column Descriptions")
    st.table(desc_df)

elif page == "KPI's Dashboard":

    # Basic KPIs
    total_orders = df['order_id'].nunique()
    total_revenue = df['total_price'].sum()
    total_customers = df['customer_name'].nunique()

    avg_order_value = total_revenue / total_orders
    avg_customer_spend = total_revenue / total_customers
    avg_items_per_order = df.groupby('order_id')['product_name'].count().mean()

    # Display KPIs in columns
    col1, col2, col3 = st.columns(3)
    col1.metric("🛒 Total Orders", f"{total_orders:,}")
    col2.metric("💰 Total Revenue", f"${total_revenue:,.2f}")
    col3.metric("👥 Total Customers", f"{total_customers:,}")

    col4, col5, col6 = st.columns(3)
    col4.metric("📦 Avg Items per Order", f"{avg_items_per_order:.2f}")
    col5.metric("🏷️ Avg Order Value", f"${avg_order_value:,.2f}")
    col6.metric("💳 Avg Customer Spend", f"${avg_customer_spend:,.2f}")

    st.write("---")

    st.subheader("📈 Revenue Over Time")
    df_sorted = df.sort_values(by= 'order_date')
    revenue_trend = df_sorted.groupby('order_date')['total_price'].sum().reset_index()
    st.plotly_chart(px.line(data_frame= revenue_trend, x= 'order_date', y= 'total_price',
    labels = {'order_date' : 'Order Date', 'total_price' : 'Revenue'}))

    # Top states by revenue
    st.subheader("🏙️ Top States by Revenue")
    state_rev = df.groupby('state')['total_price'].sum().sort_values(ascending=False).head(10).reset_index()
    st.plotly_chart(px.bar(state_rev, x='state', y='total_price', title='Top 10 States by Revenue'))

    # Top products by revenue
    st.subheader("🔥 Top Products by Revenue")
    product_rev = df.groupby('product_name')['total_price'].sum().sort_values(ascending=False).head(10).reset_index()
    st.plotly_chart(px.bar(product_rev, x='product_name', y='total_price', title='Top 10 Products by Revenue'))

elif page == 'Marketing Report':

    start_date = st.sidebar.date_input('Start Date', min_value = df.order_date.min(), max_value = df.order_date.max(), value = df.order_date.min())

    end_date = st.sidebar.date_input('End Date', min_value = df.order_date.min(), max_value = df.order_date.max(), value = df.order_date.max())

    df_filtered = df[(df.order_date >= str(start_date)) & (df.order_date <= str(end_date))]

    # What are the top products in each state ?

    All_states = df_filtered.state.unique().tolist() + ['All States']

    State = st.sidebar.selectbox('State', All_states)

    if State != 'All States':

        df_filtered = df_filtered[df_filtered.state == State]

    st.dataframe(df_filtered)

    st.subheader("🔥 Top Products by State")

    top_n = st.sidebar.slider('Top N', min_value = 1, max_value = 30, value = 5)
    products_count = df_filtered.product_name.value_counts().reset_index().head(top_n)
    st.plotly_chart(px.bar(data_frame= products_count, x= 'product_name', y= 'count'))
# Out:
# Overwriting shoping_cart.py

# %%
! streamlit run shoping_cart.py
# Out:
# ^C

# %%
import pipreqs 

# !pipreqs . --force --encoding=utf-8
# Out:
# 'C:\Users\DELL\anaconda3\envs\ai\Scripts\pipreqs.exe' was blocked by your organization's Device Guard policy.
# Contact your support person for more info.
